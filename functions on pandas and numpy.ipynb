# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'x':[1,2,3,4,5],'y':[6,7,8,9,0]},index=['a','b','c','d','e'])
df
# Out:
#    x  y
# a  1  6
# b  2  7
# c  3  8
# d  4  9
# e  5  0

# %%
df[['x']]
# Out:
#    x
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
df[['a']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[['a']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# ...

# %%
df[[0]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df[[0]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# ...

# %%
s = pd.Series({'x':[1,2,3,4,5]})
s
# Out:
# x    [1, 2, 3, 4, 5]
# dtype: object

# %%
s["x"]
# Out:
# [1, 2, 3, 4, 5]

# %%
s[0]
# Out:
# [1, 2, 3, 4, 5]

# %%
s[0][2]
# Out:
# 3

# %%
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr[0]
# Out:
# 1

# %%
arr[0,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 arr[0,1]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
arr[[0,1]]
# Out:
# array([1, 2])

# %%
arr2 = np.array([[1,2,3,4],[5,6,7,8]])
arr2
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
arr2[0]
# Out:
# array([1, 2, 3, 4])

# %%
arr2[[0,1]]
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
arr2[1][[1,2]]
# Out:
# array([6, 7])

# %%
arr2[[0,1]][[2,3]] # We can't extract random multiple items of 2D array by indexing
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 arr2[[0,1]][[2,3]]
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
arr2[[0,2],[1,3]]   # We can't extract random multiple items of 2D array by indexing
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 arr2[[0,2],[1,3]]
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
arr2[][0]   # we can't access columns values using indexing in numpy 2D array.
# Out:
#   Cell In[36], line 1
#     arr2[][0]
#          ^
# SyntaxError: invalid syntax

# %%
np.ones(4)
# Out:
# array([1., 1., 1., 1.])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye(2,2)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
np.diag((3,2,))
# Out:
# array([[3, 0, 0, 0],
#        [0, 2, 0, 0],
#        [0, 0, 4, 0],
#        [0, 0, 0, 5]])

# %%
np.diag((3,4,2,5))
# Out:
# array([[3, 0, 0, 0],
#        [0, 4, 0, 0],
#        [0, 0, 2, 0],
#        [0, 0, 0, 5]])
